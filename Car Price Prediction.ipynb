# %% [markdown]
# # Topic: Car Price Prediction

# %%
# Task-02 :Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice, 
# such as the cardataset from Kaggle. Explore the relationships between variables and identify patterns and trends in the data

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #  Step 01: Load the dataset

# %%
car_data = pd.read_csv("CAR DETAILS.csv")
car_data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
# Display basic information about the dataset

# %%
print(car_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB
# None

# %%
print(car_data.head())
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
# Step 1: Data Cleaning and Overview
print("\nSummary of Categorical Variables:")
for col in ['fuel', 'seller_type', 'transmission', 'owner']:
    print(f"{col}:\n{car_data[col].value_counts()}\n")
# Out:
# Summary of Categorical Variables:
# fuel:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64
#
# seller_type:
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64
#
# transmission:
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64
#
# owner:
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %%
print("\nSummary of Numerical Variables:")
print(car_data.describe())
# Out:
# Summary of Numerical Variables:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %% [markdown]
# # Step 02: Visualizations

# %%
# Year Distribution
plt.figure(figsize=(20, 5))
plt.subplot(1, 3, 1)
sns.histplot(car_data['year'], bins=30, kde=True, color='blue')
plt.title('Distribution of Year')
# Out:
# Text(0.5, 1.0, 'Distribution of Year')

# %%
# Selling Price Distribution
plt.figure(figsize=(20, 5))
plt.subplot(1, 3, 2)
sns.histplot(car_data['selling_price'], bins=30, kde=True, color='green')
plt.title('Distribution of Selling Price')
# Out:
# Text(0.5, 1.0, 'Distribution of Selling Price')

# %%
# KM Driven Distribution
plt.figure(figsize=(20, 5))
plt.subplot(1, 3, 3)
sns.histplot(car_data['km_driven'], bins=30, kde=True, color='purple')
plt.title('Distribution of KM Driven')
plt.tight_layout()
plt.show()

# %%
# Step 3: Visualizations - Categorical Variables
plt.figure(figsize=(14, 10))
categorical_columns = ['fuel', 'seller_type', 'transmission', 'owner']
for i, col in enumerate(categorical_columns):
    plt.subplot(2, 2, i + 1)
    sns.countplot(data=car_data, x=col, palette='viridis', order=car_data[col].value_counts().index)
    plt.title(f"Count of {col}")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17792\957322751.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=car_data, x=col, palette='viridis', order=car_data[col].value_counts().index)
# C:\Users\user\AppData\Local\Temp\ipykernel_17792\957322751.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=car_data, x=col, palette='viridis', order=car_data[col].value_counts().index)
# C:\Users\user\AppData\Local\Temp\ipykernel_17792\957322751.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# # Step 03:  Relationship Analysis

# %%
# Selling Price vs. Year
plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(data=car_data, x='year', y='selling_price', hue='fuel', alpha=0.7, palette='deep')
plt.title("Selling Price vs. Year")
plt.xlabel("Year")
plt.ylabel("Selling Price")
# Out:
# Text(0, 0.5, 'Selling Price')

# %%
# Selling Price vs. KM Driven
plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 2)
sns.scatterplot(data=car_data, x='km_driven', y='selling_price', hue='transmission', alpha=0.7, palette='muted')
plt.title("Selling Price vs. KM Driven")
plt.xlabel("Kilometers Driven")
plt.ylabel("Selling Price")
plt.xscale('log')  # Log scale for better visualization
plt.tight_layout()
plt.show()

# %%
# Step 5: Correlation Heatmap
plt.figure(figsize=(8, 6))
correlation_matrix = car_data[['year', 'selling_price', 'km_driven']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Variables")
plt.show()
